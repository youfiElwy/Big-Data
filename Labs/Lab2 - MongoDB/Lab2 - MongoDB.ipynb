# %%
# MetaData:

# Metadata for the dataset

# - Type: The type of content (e.g., Movie).
# - Title: The title of the movie.
# - Year of Release: The year the movie was released.
# - Director: The director of the movie.
# - Genre: The genre of the movie.
# - IMDB Rating: The IMDB rating of the movie.

# Example data:
# Type  | Title                      | Year of Release | Director          | Genre    | IMDB Rating
# Movie | Kiki’s Delivery Service    | 1989            | Hayao Miyazaki    | Fantasy  | 7.8
# Movie | Knives Out                 | 2019            | Rian Johnson      | Mystery  | 7.9
# Movie | Green Book                 | 2018            | Peter Farrelly    | Drama    | 8.2
# Movie | Only The Brave             | 2017            | Joseph Kosinski   | Drama    | 7.6
# Movie | Singin’ In The Rain        | 1952            | Stanley Donen     | Musical  | 8.3
# Movie | The Apartment              | 1960            | Billy Wilder      | Comedy   | 8.3
# Movie | The Book Thief             | 2013            | Brian Percival    | Drama    | 7.5
# Movie | Summer Stock               | 1950            | Charles Walters   | Musical  | 7.1
# Movie | The Terminal               | 2004            | Steven Spielberg  | Drama    | 7.4
# Movie | The Trouble with Angels    | 1966            | Ida Lupino        | Comedy   | 7.3

# %%
# !pip install pymongo
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.2/677.2 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 25.7 MB/s eta 0:00:00
# ...

# %%
import pymongo
from pymongo import MongoClient
import urllib.parse
from bson.json_util import dumps

# %%
username = urllib.parse.quote_plus('youfi') # replace <<USERNAME>> with your own MongoDB username
password = urllib.parse.quote_plus("Stecki10") # replace <<PASSWORD>> with your own MongoDB password

# url = "mongodb+srv://{}:{}@<<CLUSTERNAME>>.qgup7.mongodb.net/<<DATABASENAME>>?retryWrites=true&w=majority".format(username, password)
# replace <<CLUSTERNAME>> with your cluster's name and <<DATABASENAME>> with your database's name
url = 'mongodb+srv://youfi:Stecki10@cluster0.dr8zh86.mongodb.net/Cluster0?retryWrites=true&w=majority'
cluster = MongoClient(url)

# %%
db = cluster["Cluster0"] # replace <<DATABASENAME>> with your database's name
collection = db["watch"]

# %%
# -✔️- Reading movies from CSV into documents

import pandas as pd

df = pd.read_csv("moviestv.csv") # edit path accordingly to read from where the moviestv.csv file is
df = df.rename(columns={"Year of Release": "Year", "IMDB Rating": "Rating"})

i,j = df.shape


movies_tvshows = []

for x in range(0,4):
    movies_tvshows = movies_tvshows + [{'Type': '%s' % (df.loc[x].Type), 'Title': '%s' % (df.loc[x].Title),
                                        'Year of Release': '%d' % (df.loc[x].Year), 'Director': '%s' % (df.loc[x].Director),
                                        'Genre': '%s' % (df.loc[x].Genre), 'IMDB Rating': '%d' % (df.loc[x].Rating)} ]

# %%
# -✔️- Inserting the movies and shows into our collection

collection.insert_many(movies_tvshows)
# Out:
# InsertManyResult([ObjectId('65d07ab26ba9dcd05b75a054'), ObjectId('65d07ab26ba9dcd05b75a055'), ObjectId('65d07ab26ba9dcd05b75a056'), ObjectId('65d07ab26ba9dcd05b75a057'), ObjectId('65d07ab26ba9dcd05b75a058'), ObjectId('65d07ab26ba9dcd05b75a059'), ObjectId('65d07ab26ba9dcd05b75a05a'), ObjectId('65d07ab26ba9dcd05b75a05b'), ObjectId('65d07ab26ba9dcd05b75a05c'), ObjectId('65d07ab26ba9dcd05b75a05d'), ObjectId('65d07ab26ba9dcd05b75a05e'), ObjectId('65d07ab26ba9dcd05b75a05f'), ObjectId('65d07ab26ba9dcd05b75a060'), ObjectId('65d07ab26ba9dcd05b75a061'), ObjectId('65d07ab26ba9dcd05b75a062'), ObjectId('65d07ab26ba9dcd05b75a063'), ObjectId('65d07ab26ba9dcd05b75a064'), ObjectId('65d07ab26ba9dcd05b75a065'), ObjectId('65d07ab26ba9dcd05b75a066'), ObjectId('65d07ab26ba9dcd05b75a067'), ObjectId('65d07ab26ba9dcd05b75a068'), ObjectId('65d07ab26ba9dcd05b75a069'), ObjectId('65d07ab26ba9dcd05b75a06a'), ObjectId('65d07ab26ba9dcd05b75a06b'), ObjectId('65d07ab26ba9dcd05b75a06c')], acknowledged=True)

# %%
# -✔️- Counting how many movies and tv shows available

movie_count = collection.count_documents({"Type":"Movie"})
tvshow_count = collection.count_documents({"Type":"TV Show"})

print("There are",movie_count,"movies and",tvshow_count,"tv shows")
# Out:
# Total number of movies and TV shows: 25

# %%
# -✔️- Update an entry

# Print the original document.
# dumps is simply used for pretty printing the output.
beforeCH = collection.find({"Title":"Miracle In Cell No. 7"})
print(dumps(beforeCH,indent=3))

# Update the language to Turkish.
collection.update_one({"Title":"Miracle In Cell No. 7"},{"$set":{"Language":"Turkish"}})

# Print the updated document.
afterCH = collection.find({"Title":"Miracle In Cell No. 7"})
print(dumps(afterCH,indent=3))
# Out:
# Updated the IMDB Rating to 9.5

# %%
# -✔️- Insert a new tv show

new_show = {
    "Year of Release": 2020,
    "Director": "Jason Sudeikis",
    "Type": "TV Show",
    "Title": "Ted Lasso",
    "Genre": "Drama",
    "IMDB Rating": 8.9
}

collection.insert_one(new_show)
# Out:
# Inserted a new TV show

# %%
# -✔️- Adding a duration attribute to all movies, with default value 90 minutes

collection.update_many({"Type":"Movie"},{"$set":{"Duration":"90 Minutes"}})
# Out:
# Added 90 minutes duration to all Movies!!!

# %%
# -✔️- Deleting an show or movie released in 2017

collection.delete_many({"Year of Release":2017})
# Out:
# Deleted any show or movie released in 2017!!

# %%
# -✔️- Finding action movies

# action_movies = collection.find({"Type":"Movie","Genre":"Action"})
# print(dumps(action_movies,indent=3))

# --OR--

# -- Finding action movies
action_movies = collection.find({'Genre': 'Action'})
print('Action Movies:')
for movie in action_movies:
  print(movie)
# Out:
# Action Movies:
# {'_id': ObjectId('65d07ab26ba9dcd05b75a05f'), 'Type': 'Movie', 'Title': 'Lara Croft: Tomb Raider', 'Year of Release': '2001', 'Director': 'Simon West', 'Genre': 'Action', 'IMDB Rating': '5', 'Duration': '90 minutes'}
# {'_id': ObjectId('65d07ab26ba9dcd05b75a060'), 'Type': 'Movie', 'Title': 'Taken', 'Year of Release': '2008', 'Director': 'Pierre Morel', 'Genre': 'Action', 'IMDB Rating': '7', 'Duration': '90 minutes'}
# {'_id': ObjectId('65d07ab26ba9dcd05b75a06b'), 'Type': 'TV Show', 'Title': 'Arcane', 'Year of Release': '2021', 'Director': 'Pascal Charrue', 'Genre': 'Action', 'IMDB Rating': '9'}
# {'_id': ObjectId('65d07d106ba9dcd05b75a06d'), 'Type': 'TV Show', 'Title': 'MacGyver', 'Year of Release': '2013', 'Director': 'Mac Director', 'Genre': 'Action', 'IMDB Rating': '10.0'}

# %%
# -✔️- Getting the top rated movie and tv show

# best_movie = collection.find({"Type":"Movie"}).sort("IMDB Rating",-1).limit(1)
# best_show = collection.find({"Type":"TV Show"}).sort("IMDB Rating",-1).limit(1)

# for x in best_movie:
#     print("Best movie is",x["Title"],"from",x["Year of Release"],"with a rating of",x["IMDB Rating"])

# for x in best_show:
#     print("Best show is",x["Title"],"from",x["Year of Release"],"with a rating of",x["IMDB Rating"])


# --OR--



# -- Getting the top rated movie and tv show
top_rated_movie = collection.find_one({'Type': 'Movie'}, sort=[('IMDB Rating', pymongo.DESCENDING)])
top_rated_show = collection.find_one({'Type': 'TV Show'}, sort=[('IMDB Rating', pymongo.DESCENDING)])

formatted_top_rated_movie = dumps(top_rated_movie, indent=2)
formatted_top_rated_show = dumps(top_rated_show, indent=2)


print('Top rated movie:\n', formatted_top_rated_movie, '\n\n\n')
print('Top rated tv show:\n', formatted_top_rated_show)
# Out:
# Top rated movie:
#  {
#   "_id": {
#     "$oid": "65d07ab26ba9dcd05b75a056"
#   },
#   "Type": "Movie",
#   "Title": "Green Book",
#   "Year of Release": "2018",
#   "Director": "Peter Farrelly",
#   "Genre": "Drama",
#   "IMDB Rating": "8",
#   "Duration": "90 minutes"
# }
#
#
#
# Top rated tv show:
#  {
#   "_id": {
#     "$oid": "65d07ab26ba9dcd05b75a068"
#   },
#   "Type": "TV Show",
#   "Title": "The Wire",
#   "Year of Release": "2002",
#   "Director": "David Simon",
#   "Genre": "Drama",
#   "IMDB Rating": "9"
# }
